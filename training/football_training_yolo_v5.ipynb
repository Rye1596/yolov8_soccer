# %% [markdown]
# # 获取数据集
# 由于要进行球权分析，所以要区分球员和裁判，这里的数据集区分了球员和裁判

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="sjbNb0WqUYOezBeTD0Jb")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
print(dataset.location)
# Out:
# c:\Coding\CVexperiment\football_tracking\training\football-players-detection-1

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5n.pt data={dataset.location}/data.yaml epochs=10 imgsz=640 batch=16 device=0
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# New https://pypi.org/project/ultralytics/8.3.121 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.35 🚀 Python-3.10.16 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...
